# %%
import nltk
import nltk.corpus

# %%
nltk.download('treebank')
# Out:
# [nltk_data] Downloading package treebank to /home/leo/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# True

# %%
from nltk.corpus import treebank
from nltk.corpus import sinica_treebank

# %%
tts = treebank.tagged_sents()

# %%
tts[0]
# Out:
# [('Pierre', 'NNP'),
#  ('Vinken', 'NNP'),
#  (',', ','),
#  ('61', 'CD'),
#  ('years', 'NNS'),
#  ('old', 'JJ'),
#  (',', ','),
#  ('will', 'MD'),
#  ('join', 'VB'),
#  ('the', 'DT'),
#  ('board', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('nonexecutive', 'JJ'),
#  ('director', 'NN'),
#  ('Nov.', 'NNP'),
#  ('29', 'CD'),
#  ('.', '.')]

# %%
len(tts)
# Out:
# 3914

# %%
import conllu

# %%
dir(conllu)
# Out:
# ['TokenList',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'compat',
#  'models',
#  'parse',
#  'parse_conllu_plus_fields',
#  'parse_incr',
#  'parse_sentences',
#  'parse_token_and_metadata',
#  'parse_tree',
#  'parse_tree_incr',
#  'parser',
#  'string_to_file',
#  'unicode_literals']

# %%
base_dir = "/home/leo/projects/Datasets/text/UniversalDependencies/ud-treebanks-v2.4"

# %%
import os, sys

# %%
tblist = os.listdir(base_dir)

# %%
tblist = sorted(tblist)

# %%
tblist
# Out:
# ['UD_Afrikaans-AfriBooms',
#  'UD_Akkadian-PISANDUB',
#  'UD_Amharic-ATT',
#  'UD_Ancient_Greek-PROIEL',
#  'UD_Ancient_Greek-Perseus',
#  'UD_Arabic-NYUAD',
#  'UD_Arabic-PADT',
#  'UD_Arabic-PUD',
#  'UD_Armenian-ArmTDP',
#  'UD_Assyrian-AS',
#  'UD_Bambara-CRB',
#  'UD_Basque-BDT',
#  'UD_Belarusian-HSE',
#  'UD_Breton-KEB',
#  'UD_Bulgarian-BTB',
#  'UD_Buryat-BDT',
#  'UD_Cantonese-HK',
#  'UD_Catalan-AnCora',
#  'UD_Chinese-CFL',
#  'UD_Chinese-GSD',
#  'UD_Chinese-HK',
#  'UD_Chinese-PUD',
#  'UD_Classical_Chinese-Kyoto',
#  'UD_Coptic-Scriptorium',
#  'UD_Croatian-SET',
#  'UD_Czech-CAC',
#  'UD_Czech-CLTT',
#  'UD_Czech-FicTree',
#  'UD_Czech-PDT',
#  'UD_Czech-PUD',
#  'UD_Danish-DDT',
#  'UD_Dutch-Alpino',
#  'UD_Dutch-LassySmall',
#  'UD_English-ESL',
#  'UD_English-EWT',
#  'UD_English-GUM',
#  'UD_English-LinES',
#  'UD_English-PUD',
#  'UD_English-ParTUT',
#  'UD_Erzya-JR',
#  'UD_Estonian-EDT',
#  'UD_Estonian-EWT',
#  'UD_Faroese-OFT',
#  'UD_Finnish-FTB',
# ...

# %%
frdirs = [d for d in tblist if "French" in d]

# %%
frdirs
# Out:
# ['UD_French-FQB',
#  'UD_French-FTB',
#  'UD_French-GSD',
#  'UD_French-PUD',
#  'UD_French-ParTUT',
#  'UD_French-Sequoia',
#  'UD_French-Spoken',
#  'UD_Old_French-SRCMF']

# %%
fname = "/home/leo/projects/Datasets/text/UniversalDependencies/ud-treebanks-v2.4/UD_French-PUD/fr_pud-ud-test.conllu"
f = open(fname,"r")

# %%
frpud = conllu.parse(f.read())

# %%
tl0 = frpud[0]

# %%
len(tl0)
# Out:
# 51

# %%
frpud[0][:]
# Out:
# [OrderedDict([('id', 1),
#               ('form', '«'),
#               ('lemma', '_'),
#               ('upostag', 'PUNCT'),
#               ('xpostag', '``'),
#               ('feats', None),
#               ('head', 29),
#               ('deprel', 'punct'),
#               ('deps', None),
#               ('misc', None)]),
#  OrderedDict([('id', 2),
#               ('form', 'Alors'),
#               ('lemma', '_'),
#               ('upostag', 'ADV'),
#               ('xpostag', 'RB'),
#               ('feats', None),
#               ('head', 12),
#               ('deprel', 'mark'),
#               ('deps', None),
#               ('misc', None)]),
#  OrderedDict([('id', 3),
#               ('form', 'que'),
#               ('lemma', '_'),
#               ('upostag', 'SCONJ'),
#               ('xpostag', 'IN'),
#               ('feats', None),
#               ('head', 2),
#               ('deprel', 'fixed'),
#               ('deps', None),
#               ('misc', None)]),
# ...

# %%
frpudsentences = list(frpud)

# %%
frpudsentences[:10]
# Out:
# [TokenList<«, Alors, que, la, plus, grande, partie, de, la, transition, numérique, est, sans, précédent, aux, à, les, États-Unis, ,, la, transition, sereine, du, de, le, pouvoir, ,, elle, ,, ne, l', est, pas, ,, », a, publié, Kori, Schulman, ,, assistante, spéciale, d', Obama, ,, dans, un, blog, ce, lundi, .>,
#  TokenList<Pour, ceux, qui, suivent, la, transition, des, de, les, réseaux, sociaux, sur, le, Capitole, ,, cela, va, être, un, peu, différent, .>,
#  TokenList<Mais, ,, en, rupture, avec, sa, rhétorique, précédente, concernant, la, réduction, de, l', immigration, ,, le, candidat, du, de, le, parti, républicain, a, annonçé, qu', en, tant, que, président, ,, il, autoriserait, un, «, nombre, considérable, », d', immigrants, légaux, fondé, sur, un, «, principe, du, de, le, mérite, », .>,
# ...
